# %% [markdown]
# # Bayesian Statistical Inference II
#
# *N. Hernitschek, 2022*
#
# This is the seventh Jupyter notebook for **ASTR 3890 - Selected Topics: Data Science for Large Astronomical Surveys (Spring 2022)**.
# This Jupyter notebook gives an introduction to frequentist statistical inference and maximum likelihood estimation.
#
# It is based on code from the textbook
#
# Statistics, Data Mining and Machine Learning in Astronomy: A Practical Python Guide for the Analysis of
# Survey Data - Z. Ivezic, A. J. Connolly, J. T. VanderPlas, A. Gray
#
# as well as on the [MCMC Sampling Tutorial](https://twiecki.io/blog/2015/11/10/mcmc-sampling) by Thomas Wiecki.
#
# ***Exercises required for class participation are in <font color='red'>red</font>.***

# %% [markdown]
# ---
# ## Contents
# * [Python Packages for MCMC](#first-bullet)
# * [MCMC with emcee](#second-bullet)
# * [MCMC with pyMC3](#third-bullet)

# %% [markdown]
# ### Package Installation
#
# ***In case you haven't done so already:*** Please pause for a few minutes and install these packages `emcee` and `pymc3` before executing code from today's notebook.

# %%
# !pip3 install emcee
# Out:
# Requirement already satisfied: emcee in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (3.1.1)
# Requirement already satisfied: numpy in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from emcee) (1.21.2)

# %%
# !pip3 install pymc3
# Out:
# Requirement already satisfied: pymc3 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (3.11.4)
# Requirement already satisfied: semver>=2.13.0 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from pymc3) (2.13.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from pymc3) (1.21.2)
# Requirement already satisfied: scipy>=1.2.0 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from pymc3) (1.7.3)
# Requirement already satisfied: theano-pymc==1.1.2 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from pymc3) (1.1.2)
# Requirement already satisfied: cachetools>=4.2.1 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from pymc3) (5.0.0)
# Requirement already satisfied: fastprogress>=0.2.0 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from pymc3) (1.0.2)
# Requirement already satisfied: patsy>=0.5.1 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from pymc3) (0.5.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from pymc3) (3.10.0.2)
# Requirement already satisfied: arviz>=0.11.0 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from pymc3) (0.11.4)
# Requirement already satisfied: pandas>=0.24.0 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from pymc3) (1.4.1)
# Requirement already satisfied: dill in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from pymc3) (0.3.4)
# Requirement already satisfied: filelock in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from theano-pymc==1.1.2->pymc3) (3.6.0)
# Requirement already satisfied: packaging in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from arviz>=0.11.0->pymc3) (21.3)
# Requirement already satisfied: xarray>=0.16.1 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from arviz>=0.11.0->pymc3) (2022.3.0)
# Requirement already satisfied: setuptools>=38.4 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from arviz>=0.11.0->pymc3) (58.0.4)
# Requirement already satisfied: matplotlib>=3.0 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from arviz>=0.11.0->pymc3) (3.5.0)
# Requirement already satisfied: netcdf4 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from arviz>=0.11.0->pymc3) (1.5.8)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from pandas>=0.24.0->pymc3) (2021.3)
# Requirement already satisfied: six in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from patsy>=0.5.1->pymc3) (1.16.0)
# Requirement already satisfied: cftime in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from netcdf4->arviz>=0.11.0->pymc3) (1.6.0)

# %%
# !pip3 install git+https://github.com/dfm/acor@master
# Out:
# Collecting git+https://github.com/dfm/acor@master
#   Cloning https://github.com/dfm/acor (to revision master) to /private/var/folders/y2/qkxvcl115213lnrfc1ty1dy00000gn/T/pip-req-build-8y2kvlrv
#   Running command git clone -q https://github.com/dfm/acor /private/var/folders/y2/qkxvcl115213lnrfc1ty1dy00000gn/T/pip-req-build-8y2kvlrv
#   Running command git checkout -b master --track origin/master
#   Switched to a new branch 'master'
#   Branch 'master' set up to track remote branch 'master' from 'origin'.
#   Resolved https://github.com/dfm/acor to commit b55eb8efa7df6c73b6f3f0c9b64fa1c801e8f821
# Requirement already satisfied: numpy in /Users/sambianco/opt/anaconda3/envs/astr3890/lib/python3.8/site-packages (from acor==1.1.1) (1.21.2)

# %% [markdown]
# ## 1. Python Packages for MCMC <a class="anchor" id="first-bullet"></a>
#
# Let's look at some more evolved examples. We will use two popular python modules: `emcee` and `PyMC`.
# Quoting Jake VanderPlas for `emcee` and `PyMC`.
# [Jake's blog:](http://jakevdp.github.io/blog/2014/06/14/frequentism-and-bayesianism-4-bayesian-in-python/)
#
# ### emcee
#
# > The emcee package (*also known as MCMC Hammer, which is in the running for best Python package name in history*) is a Pure Python package written by Astronomer Dan Foreman-Mackey. It is a lightweight package which implements a fairly sophisticated Affine-invariant Hamiltonian MCMC. Because the package is pure Python (i.e. it contains no compiled extensions) it is extremely easy to install; with pip, simply type at the command-line "pip install emcee".
#
# Emcee simply requires you to pass it a Python function which returns a value proportional to the log-posterior probability, and returns samples from that posterior.*
#
# ### PyMC
#
# > The PyMC package has many more features than emcee, including built-in support for efficient sampling of common prior distributions. PyMC by default uses the classic Metropolis-Hastings sampler, one of the earliest MCMC algorithms. For performance, it uses compiled fortran libraries, so it is less trivial to install using tools like pip. PyMC binaries for many systems can be quite easily installed with conda.*
#
# More details about PyMC are available from [the pyMC User Guide](https://pymc-devs.github.io/pymc/), but note that we are going to be using [PyMC3](https://docs.pymc.io/).

# %%
# Execute this cell
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

from scipy import integrate
from scipy.stats import norm
from scipy.stats import cauchy
from astroML.plotting import hist
from astroML.plotting.mcmc import convert_to_stdev
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=8, usetex=False)
from astroML.plotting.mcmc import convert_to_stdev
import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# ## 2. MCMC with emcee<a class="anchor" id="first-bullet"></a>

# %% [markdown]
# Import `emcee` and generate some homoescedastic Gaussian data. We'll assume the standard deviation is know, so we're only estimating $\mu$.

# %%
import emcee

np.random.seed(21)
Ndata = 100
mu = 1.0
sigma = 0.5 # assumed known 
data = stats.norm(mu, sigma).rvs(Ndata)

# %% [markdown]
# Define all the relevant functions.

# %%
def Likelihood(x, sigma, data):
    # Gaussian likelihood 
    return np.prod(np.exp(-(data-x)**2 /2 /sigma**2))

def Prior(x):
    return 1.0 / 10   # flat: it cancels out and has no effect 

def myPosterior(x, sigma, data):
    return Likelihood(x, sigma, data) * Prior(x)

# emcee wants ln of posterior pdf
def myLogPosterior(x, sigma, data):
    return np.log(myPosterior(x, sigma, data))

# %% [markdown]
# `emcee` combines multiple "walkers", each of which is its own MCMC chain. The number of trace results will be nwalkers $\times$ nsteps.

# %%
ndim = 1  # number of parameters in the model
nwalkers = 6  # number of MCMC walkers
burn = 1000  # "burn-in" period to let chains stabilize
nsteps = 5000  # number of MCMC steps to take **for each walker**

# initialize theta 
np.random.seed(0)
starting_guesses = np.random.random((nwalkers, ndim))

# the function call where all the work happens: 
sampler = emcee.EnsembleSampler(nwalkers, ndim, myLogPosterior, args=[sigma, data])
sampler.run_mcmc(starting_guesses, nsteps)
 
# sampler.chain is of shape (nwalkers, nsteps, ndim)
# throw-out the burn-in points and reshape:
emcee_trace  = sampler.chain[:, burn:, :].reshape(-1, ndim)

print("done")
# Out:
# done

# %%
data.shape
# Out:
# (100,)

# %%
print(sampler.chain.shape) #original chain structure
print(emcee_trace.shape) #burned and flattened chain
# Out:
# (6, 5000, 1)
# (24000, 1)

# %%
# plot 
fig = plt.figure(figsize=(9, 5))
fig.subplots_adjust(left=0.11, right=0.95, 
                    wspace=0.35, bottom=0.18)

chainE = emcee_trace #[0]
M = np.size(chainE)

ax1 = fig.add_subplot(121)
xgrid = np.linspace(1, M, M)
plt.plot(xgrid, chainE)
ax1.axis([0, M, np.min(chainE), 1.1*np.max(chainE)])
plt.xlabel('number')
plt.ylabel('chain')

# plot running mean: 
meanC = [np.mean(chainE[:int(N)]) for N in xgrid]
ax1.plot(xgrid, meanC, c='red', label='chain mean') 
ax1.plot(xgrid, 0*xgrid + np.mean(data),
         c='yellow',label='data mean')
ax1.legend()

ax2 = fig.add_subplot(122)
# skip first burn samples
Nburn = 1000
Nchain = np.size(chainE[xgrid>burn])
Nhist, bins, patches = plt.hist(chainE[xgrid>Nburn], 
                                bins='auto', histtype='stepfilled')

# plot expectations based on central limit theorem
binwidth = bins[1] - bins[0]
muCLT = np.mean(data)
sigCLT = np.std(data)/np.sqrt(Ndata)
muGrid = np.linspace(0.7, 1.3, 500)
gauss = Nchain * binwidth * stats.norm(muCLT, sigCLT).pdf(muGrid) 
ax2.plot(muGrid, gauss, c='red') 

ax2.set_ylabel('p(chain)')
ax2.set_xlabel('chain values')
ax2.set_xlim(0.7, 1.3)
ax2.set_ylim(0, 1.2*np.max(gauss))
ax2.set_title(r'Chain from emcee')
# Out:
# Text(0.5, 1.0, 'Chain from emcee')

# %% [markdown]
# ## 3. MCMC with pyMC3<a class="anchor" id="third-bullet"></a>
#
# Now we will use pyMC3 to get a 2-dimensional posterior pdf for location and scale parameters using a sample drawn from a **Cauchy distribution**. Remember a Cauchy distribution formally has no mean or standard deviation because its tails fall off shallower than $1/x^2$.
#
# The following is code adapted from Figure 5.22 of the textbook. Initially, we load in `PyMC3` and define the Cauchy log likelihood.
#
# ***NOTE:*** The code here for the Cauchy likelihood is actually only for when we look at the analytic estimate, since `PyMC3` has ready-made modules for many standard functions!

# %%
from scipy.stats import cauchy
import pymc3 as pm

if "setup_text_plots" not in globals():
    from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=8, usetex=False)

def cauchy_logL(xi, sigma, mu):
    """Equation 5.74: cauchy likelihood"""
    xi = np.asarray(xi)
    n = xi.size
    shape = np.broadcast(sigma, mu).shape

    xi = xi.reshape(xi.shape + tuple([1 for s in shape]))

    return ((n - 1) * np.log(sigma)
            - np.sum(np.log(sigma ** 2 + (xi - mu) ** 2), 0))

# %% [markdown]
# Generate some data from the Cauchy distribution.

# %%
# ----------------------------------------------------------------------
# Draw the sample from a Cauchy distribution
np.random.seed(44)
mu_0 = 0
gamma_0 = 2
xi = cauchy(mu_0, gamma_0).rvs(10)

# %% [markdown]
# Set up the `PyMC3` model.

# %%
# ----------------------------------------------------------------------
# Set up and run MCMC:
with pm.Model():
    mu = pm.Uniform('mu', -5, 5) #uniform in Cauchy mu
    log_gamma = pm.Uniform('log_gamma', -10, 10) #uniform in log of Cauchy gamma

    # set up our observed variable x
    # i.e. read this as 'x is distributed as a Cauchy variable'
    x = pm.Cauchy('x', mu, np.exp(log_gamma), observed=xi)

    trace = pm.sample(draws=12000, tune=1000, cores=1)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [log_gamma, mu]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='13000' class='' max='13000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [13000/13000 00:03<00:00 Sampling chain 0, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='13000' class='' max='13000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [13000/13000 00:03<00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 12_000 draw iterations (2_000 + 24_000 draws total) took 7 seconds.

# %% [markdown]
# You may have seen some output messages along the lines of "Auto-assigning NUTS sampler...". `PyMC3` is very sophisticated, and will automatically decide for you the best tools for the job.
#
# In this case, it decided you needed **No-U-Turn Hamiltonian gradient-based sampling**, where gradient information about the Cauchy likelihood helped in the exploration of parameter space.

# %%
# compute histogram of results to plot below
L_MCMC, mu_bins, gamma_bins = np.histogram2d(trace['mu'],
                                             np.exp(trace['log_gamma']),
                                             bins=(np.linspace(-5, 5, 41),
                                                   np.linspace(0, 5, 41)))
L_MCMC[L_MCMC == 0] = 1E-16  # prevents zero-division errors

# ----------------------------------------------------------------------
# Compute likelihood analytically for comparison
mu = np.linspace(-5, 5, 70)
gamma = np.linspace(0.1, 5, 70)
logL = cauchy_logL(xi, gamma[:, np.newaxis], mu)
logL -= logL.max()

p_mu = np.exp(logL).sum(0)
p_mu /= p_mu.sum() * (mu[1] - mu[0])

p_gamma = np.exp(logL).sum(1)
p_gamma /= p_gamma.sum() * (gamma[1] - gamma[0])

hist_mu, bins_mu = np.histogram(trace['mu'], bins=mu_bins, density=True)
hist_gamma, bins_gamma = np.histogram(np.exp(trace['log_gamma']),
                                      bins=gamma_bins, density=True)

# %%
# ----------------------------------------------------------------------
# plot all the results
fig = plt.figure(figsize=(5, 5))

# first axis: likelihood contours
ax1 = fig.add_axes((0.4, 0.4, 0.55, 0.55))
ax1.xaxis.set_major_formatter(plt.NullFormatter())
ax1.yaxis.set_major_formatter(plt.NullFormatter())

ax1.contour(mu, gamma, convert_to_stdev(logL),
            levels=(0.683, 0.955, 0.997),
            colors='b', linestyles='dashed')

ax1.contour(0.5 * (mu_bins[:-1] + mu_bins[1:]),
            0.5 * (gamma_bins[:-1] + gamma_bins[1:]),
            convert_to_stdev(np.log(L_MCMC.T)),
            levels=(0.683, 0.955, 0.997),
            colors='k')

# second axis: marginalized over mu
ax2 = fig.add_axes((0.1, 0.4, 0.29, 0.55))
ax2.xaxis.set_major_formatter(plt.NullFormatter())
ax2.plot(hist_gamma, 0.5 * (bins_gamma[1:] + bins_gamma[:-1]
                            - bins_gamma[1] + bins_gamma[0]),
         '-k', drawstyle='steps')
ax2.plot(p_gamma, gamma, '--b')
ax2.set_ylabel(r'$\gamma$')
ax2.set_ylim(0, 5)

# third axis: marginalized over gamma
ax3 = fig.add_axes((0.4, 0.1, 0.55, 0.29))
ax3.yaxis.set_major_formatter(plt.NullFormatter())
ax3.plot(0.5 * (bins_mu[1:] + bins_mu[:-1]), hist_mu,
         '-k', drawstyle='steps-mid')
ax3.plot(mu, p_mu, '--b')
ax3.set_xlabel(r'$\mu$')
plt.xlim(-5, 5)

plt.show()

# %% [markdown]
# The resulting 2D joint posterior pdf corner plot shows analytic results as blue dashed lines, and MCMC sampling results as black contours.

# %% [markdown]
# <font color='red'>Now create trace plots and interprete them. It will helpful if you take a look at the documentation for both `emcee` and `pymc3` for doing so.</font>
#
# - Make traceplots in $\mu$ and $\sigma$, and $\mu$ and $\gamma$, respectively.
# - Describe/ discuss where you should cut off burn-in.
# - Compute the autocorrelation length of the chain.
# - Using `corner`, make a corner plot that has labels, shows titles, and has $68\%$ and $95\%$ quantiles and levels. Hint: you can start with this code snipplet:
# `import corner
# corner.corner(sampler.flatchain, labels=['mu', 'sigma']);`

# %%
# Make traceplot for mu and log_gamma
fig = plt.figure(figsize=(15, 5))

mu_chain = trace['mu']
log_gam_chain = trace['log_gamma']
M = np.size(mu_chain)

# Plot mu trace
xgrid = np.linspace(1, M, M)
plt.plot(xgrid, mu_chain, label='mu')
plt.axis([0, M, np.min(mu_chain), 1.1*np.max(mu_chain)])

# Plot log gamma trace
plt.plot(xgrid, log_gam_chain, c='yellow', label='log gamma')

plt.xlabel('Step')
plt.ylabel('Chain')

# plot running mean: 
mean_mu = [np.mean(mu_chain[:int(N)]) for N in xgrid]
plt.plot(xgrid, mean_mu, c='red', label='chain mean - mu') 

mean_gam = [np.mean(log_gam_chain[:int(N)]) for N in xgrid]
plt.plot(xgrid, mean_gam, c='purple', label='chain mean - log gamma') 

plt.legend()
plt.show()

# %% [markdown]
# The blue lines give the value for mu at each step in the chain. The yellow lines give the value for log_gamma at each step. The red line is the running mean for the mu chain, and the purple line is the running mean for the log_gamma chain. The high variability signals to me that the parameters are mixing well and moving across parameter space efficeintly.

# %%
# Make another traceplot for mu and log_gamma, but zoom in on first steps
fig = plt.figure(figsize=(15, 5))

mu_chain = trace['mu']
log_gam_chain = trace['log_gamma']
M = np.size(mu_chain)

# Plot mu trace
xgrid = np.linspace(1, M, M)
plt.plot(xgrid, mu_chain, label='mu')
plt.axis([0, M, np.min(trace['mu']), 1.1*np.max(trace['mu'])])

# Plot log gamma trace
plt.plot(xgrid, log_gam_chain, c='yellow', label='log gamma')

# plot running mean: 
mean_mu = [np.mean(mu_chain[:int(N)]) for N in xgrid]
plt.plot(xgrid, mean_mu, c='red', label='chain mean - mu') 

mean_gam = [np.mean(log_gam_chain[:int(N)]) for N in xgrid]
plt.plot(xgrid, mean_gam, c='purple', label='chain mean - log gamma') 

plt.title('Trace plot for $\mu$ and log $\gamma$')
plt.xlabel('Step')
plt.ylabel('Chain')
plt.xlim(0, 2000)
plt.legend()
plt.show()

# %% [markdown]
# In MCMC, the process must be stationary, and the chain statistics should look the same in each part of the chain. This is not the case in early steps of the chain, so the solution is to discard the first few steps, or the burn-in phase.
#
# Burn-in should be cut off when the running means of mu and log_gamma start to stabilize. At around 500 steps into the process, the running means look pretty good. However, I wouldn't say that they are completely stable until around the 1000th step.

# %%
# Compute the autocorrelation length of the chain using pymc3 function

autocorr_mu = pm.autocorr(mu_chain)
autocorr_gam = pm.autocorr(log_gam_chain)

print(autocorr_mu, '\n', autocorr_gam)
# Out:
# [ 1.00000000e+00  2.80195261e-01  1.06344073e-01 ... -5.16943798e-05
#   5.30856903e-05 -1.89520295e-05]
#  [ 1.00000000e+00  3.23374134e-01  1.67984148e-01 ... -5.00859289e-05
#   2.71412948e-05  2.85683162e-06]

# %%
# Plot autocorrelation length as a function of steps
fig = plt.figure(figsize=(12, 8))
ax = fig.subplots(2, 1)

# Plot mu autocorrelation
ax[0].plot(xgrid, autocorr_mu, label='mu')
ax[0].set_xlabel('Step')
ax[0].set_ylabel('Autocorrelation')
ax[0].set_xlim(-500, 24000)
ax[0].set_ylim(-0.1, 1)
ax[0].set_title('Autocorrelation for $\mu$')

# Plot log gamma autocorrelation
ax[1].plot(xgrid, autocorr_gam, c='red', label='log gamma')
ax[1].set_xlabel('Step')
ax[1].set_ylabel('Autocorrelation')
ax[1].set_xlim(-500, 24000)
ax[1].set_ylim(-0.1, 1)
ax[1].set_title('Autocorrelation for log $\gamma$')

plt.tight_layout()
plt.show()

# %%
# Make corner plot
mu = np.mean(mu_chain)
log_gamma = np.mean(log_gam_chain)
corner.corner(trace, labels=['$\mu$', 'log $\gamma$'], 
              quantiles=[0.68, 0.95], verbose=True, show_titles=True,
              truths=dict(mu=mu, log_gamma=log_gamma));
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# Quantiles:
# [(0.68, 0.13284074076813823), (0.95, 1.0179578662572972)]
# Quantiles:
# [(0.68, 0.2882208521820598), (0.95, 0.8225923371269035)]

# %% [markdown]
# ## Summary <a class="anchor" id="fourth-bullet"></a>
#
# At this point, all of you should have:
# * seen two example implementations of MCMC
# * seen and understood how and why to make diagnosis plots such as trace plots.
